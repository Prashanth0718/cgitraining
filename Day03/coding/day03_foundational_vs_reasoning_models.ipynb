# %%
# %%capture
# !pip install -- upgrade openai tiktoken pandas tabulate

# %%
import os
from getpass import getpass
from google.colab import userdata
api_key = None

# Try Colab's Secrets manager first
try:
    from google.colab import userdata
    api_key = userdata.get('OPENAI_KEY')
except Exception:
    api_key = None

# Fall back to environment variable, then manual entry
if not api_key:
  api_key = userdata.get("OPEN_AI_KEY")

if not api_key:
    api_key = getpass("Enter your OPENAI_KEY (input hidden): ")

os.environ["OPENAI_KEY"] = api_key
os.environ["OPENAI_API_KEY"] = api_key  # the SDK looks for this name by default
print("✅ API key loaded:", "*" * 8 + api_key[-4:] if len(api_key) > 4 else "set")
# Out:
# ✅ API key loaded: ********4xcA

# %%
from openai import OpenAI

client = OpenAI(api_key=os.environ["OPENAI_KEY"])
print("Client ready.")

FOUNDATIONAL_MODEL = "gpt-4o-mini"   # swap for "gpt-4o" for a stronger non-reasoning baseline
REASONING_MODEL    = "o4-mini"        # swap for "o3" for a stronger reasoning model

print(f"Foundational model : {FOUNDATIONAL_MODEL}")
print(f"Reasoning model    : {REASONING_MODEL}")

print(f"Foundational model : {FOUNDATIONAL_MODEL}")
print(f"Reasoning model    : {REASONING_MODEL}")
# Out:
# Client ready.
# Foundational model : gpt-4o-mini
# Reasoning model    : o4-mini
# Foundational model : gpt-4o-mini
# Reasoning model    : o4-mini

# %%
import time

def call_foundational(prompt, model=FOUNDATIONAL_MODEL, temperature=0.2, max_tokens=800):
    start = time.time()
    resp = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=temperature,
        max_tokens=max_tokens,
    )
    elapsed = time.time() - start
    return {
        "model": model,
        "type": "foundational",
        "answer": resp.choices[0].message.content,
        "elapsed_sec": round(elapsed, 2),
        "prompt_tokens": resp.usage.prompt_tokens,
        "completion_tokens": resp.usage.completion_tokens,
        "reasoning_tokens": 0,
        "total_tokens": resp.usage.total_tokens,
    }

def call_reasoning(prompt, model=REASONING_MODEL, reasoning_effort="medium", max_completion_tokens=2000):
    start = time.time()
    resp = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        reasoning_effort=reasoning_effort,
        max_completion_tokens=max_completion_tokens,
    )
    elapsed = time.time() - start
    usage = resp.usage
    reasoning_tokens = 0
    details = getattr(usage, "completion_tokens_details", None)
    if details is not None:
        reasoning_tokens = getattr(details, "reasoning_tokens", 0) or 0
    return {
        "model": model,
        "type": "reasoning",
        "answer": resp.choices[0].message.content,
        "elapsed_sec": round(elapsed, 2),
        "prompt_tokens": usage.prompt_tokens,
        "completion_tokens": usage.completion_tokens,
        "reasoning_tokens": reasoning_tokens,
        "total_tokens": usage.total_tokens,
    }

# %%
prompts = {
    "logic_puzzle": (
        "Five friends (Ana, Ben, Cara, Dan, Ella) sit in a row of 5 seats "
        "numbered 1 to 5 left to right. Clues: "
        "(1) Ana sits immediately left of Ben. "
        "(2) Cara does not sit at either end. "
        "(3) Dan sits somewhere to the right of Ella. "
        "(4) Ella is not in seat 1. "
        "(5) Ben is not in seat 5. "
        "Work out the exact seating order from seat 1 to seat 5, and briefly "
        "justify each step."
    ),
    "math_problem": (
        "A tank is filled by Pipe A in 6 hours and by Pipe B in 4 hours. "
        "Pipe C, working alone, can drain a full tank in 8 hours. "
        "If all three pipes are opened together starting with an empty tank, "
        "how long will it take to fill the tank? Show your work and give an "
        "exact fraction, then a decimal rounded to 2 places."
    ),
    "planning_task": (
        "You must schedule 4 tasks (T1: 3 hrs, T2: 2 hrs, T3: 4 hrs, T4: 1 hr) "
        "across 2 workers over an 8-hour day so that: total time per worker "
        "does not exceed 8 hours, T3 must start before T1 can start, and "
        "T2 and T4 must be done by the same worker. Provide a valid "
        "assignment and timeline, and explain why it satisfies every "
        "constraint."
    ),
}

for k, v in prompts.items():
    print(f"--- {k} ---\n{v}\n")
# Out:
# --- logic_puzzle ---
# Five friends (Ana, Ben, Cara, Dan, Ella) sit in a row of 5 seats numbered 1 to 5 left to right. Clues: (1) Ana sits immediately left of Ben. (2) Cara does not sit at either end. (3) Dan sits somewhere to the right of Ella. (4) Ella is not in seat 1. (5) Ben is not in seat 5. Work out the exact seating order from seat 1 to seat 5, and briefly justify each step.
#
# --- math_problem ---
# A tank is filled by Pipe A in 6 hours and by Pipe B in 4 hours. Pipe C, working alone, can drain a full tank in 8 hours. If all three pipes are opened together starting with an empty tank, how long will it take to fill the tank? Show your work and give an exact fraction, then a decimal rounded to 2 places.
#
# --- planning_task ---
# You must schedule 4 tasks (T1: 3 hrs, T2: 2 hrs, T3: 4 hrs, T4: 1 hr) across 2 workers over an 8-hour day so that: total time per worker does not exceed 8 hours, T3 must start before T1 can start, and T2 and T4 must be done by the same worker. Provide a valid assignment and timeline, and explain why it satisfies every constraint.

# %%
results = []

for name, prompt in prompts.items():
    print(f"Running '{name}' on {FOUNDATIONAL_MODEL} (foundational)...")
    f_res = call_foundational(prompt)
    f_res["task"] = name
    results.append(f_res)

    print(f"Running '{name}' on {REASONING_MODEL} (reasoning)...")
    r_res = call_reasoning(prompt)
    r_res["task"] = name
    results.append(r_res)

print("\nDone.")
# Out:
# Running 'logic_puzzle' on gpt-4o-mini (foundational)...
# Running 'logic_puzzle' on o4-mini (reasoning)...
# Running 'math_problem' on gpt-4o-mini (foundational)...
# Running 'math_problem' on o4-mini (reasoning)...
# Running 'planning_task' on gpt-4o-mini (foundational)...
# Running 'planning_task' on o4-mini (reasoning)...
#
# Done.

# %%
import pandas as pd

df = pd.DataFrame(results)[
    ["task", "type", "model", "elapsed_sec", "prompt_tokens",
     "completion_tokens", "reasoning_tokens", "total_tokens"]
]
df
# Out:
#             task          type        model  elapsed_sec  prompt_tokens  \
# 0   logic_puzzle  foundational  gpt-4o-mini         6.32            117
# 1   logic_puzzle     reasoning      o4-mini        10.77            116
# 2   math_problem  foundational  gpt-4o-mini         7.25             84
# 3   math_problem     reasoning      o4-mini         3.22             83
# 4  planning_task  foundational  gpt-4o-mini         3.88            105
# 5  planning_task     reasoning      o4-mini         8.75            104
#
#    completion_tokens  reasoning_tokens  total_tokens
# 0                616                 0           733
# 1               2000              2000          2116
# 2                793                 0           877
# 3                407               256           490
# 4                439                 0           544
# 5               1445              1088          1549

# %%
for name in prompts:
    print("=" * 90)
    print(f"TASK: {name}")
    print("=" * 90)
    for res in results:
        if res["task"] != name:
            continue
        print(f"\n### {res['type'].upper()} MODEL: {res['model']} "
              f"(⏱ {res['elapsed_sec']}s, total tokens {res['total_tokens']}, "
              f"reasoning tokens {res['reasoning_tokens']})\n")
        print(res["answer"])
    print()
# Out:
# ==========================================================================================
# TASK: logic_puzzle
# ==========================================================================================
#
# ### FOUNDATIONAL MODEL: gpt-4o-mini (⏱ 6.32s, total tokens 733, reasoning tokens 0)
#
# To solve the seating arrangement of the five friends (Ana, Ben, Cara, Dan, Ella), we will analyze the clues step by step.
#
# 1. **Clue 1**: Ana sits immediately left of Ben.
#    - This means Ana and Ben must be seated together, with Ana in a lower-numbered seat than Ben. Possible pairs of seats for Ana and Ben are (1,2), (2,3), (3,4), and (4,5).
#
# 2. **Clue 2**: Cara does not sit at either end.
#    - This means Cara can only sit in seats 2, 3, or 4.
#
# 3. **Clue 3**: Dan sits somewhere to the right of Ella.
#    - This means Ella must be in a seat to the left of Dan.
#
# 4. **Clue 4**: Ella is not in seat 1.
#    - Therefore, Ella can only be in seats 2, 3, or 4.
#
# 5. **Clue 5**: Ben is not in seat 5.
#    - This means Ben can only be in seats 1, 2, 3, or 4.
#
# Now, let's analyze the implications of these clues:
#
# - Since Ana must sit immediately left of Ben, if we consider the possible pairs:
#   - If Ana and Ben are in (1,2), then Ella cannot be in seat 1 (Clue 4), so this pair is not possible.
#   - If Ana and Ben are in (2,3), then Cara cannot be in seat 2 (Clue 2), so this pair is not possible.
#   - If Ana and Ben are in (3,4), then Cara can be in seat 2, which is valid.
#   - If Ana and Ben are in (4,5), then Ben cannot be in seat 5 (Clue 5), so this pair is not possible.
#
# Thus, the only valid pair for Ana and Ben is (3,4).
#
# Now we have:
# - Seats 3 and 4: Ana and Ben (Ana in 3, Ben in 4).
# - This leaves seats 1, 2, and 5 for Cara, Dan, and Ella.
#
# Since Cara cannot be in seat 1 or 5 (Clue 2), she must be in seat 2. This leaves seats 1 and 5 for Ella and Dan.
#
# Since Ella cannot be in seat 1 (Clue 4), Ella must be in seat 5, and Dan must be in seat 1.
#
# Now we have:
# - Seat 1: Dan
# - Seat 2: Cara
# - Seat 3: Ana
# - Seat 4: Ben
# - Seat 5: Ella
#
# Thus, the final seating order from seat 1 to seat 5 is:
# 1. Dan
# 2. Cara
# 3. Ana
# 4. Ben
# 5. Ella
#
# This arrangement satisfies all the clues provided.
#
# ### REASONING MODEL: o4-mini (⏱ 10.77s, total tokens 2116, reasoning tokens 2000)
#
#
#
# ==========================================================================================
# TASK: math_problem
# ==========================================================================================
#
# ### FOUNDATIONAL MODEL: gpt-4o-mini (⏱ 7.25s, total tokens 877, reasoning tokens 0)
#
# To solve the problem, we first need to determine the rates at which each pipe fills or drains the tank.
#
# 1. **Rate of Pipe A**:
#    Pipe A can fill the tank in 6 hours. Therefore, its rate is:
#    \[
#    \text{Rate of Pipe A} = \frac{1 \text{ tank}}{6 \text{ hours}} = \frac{1}{6} \text{ tanks per hour}
#    \]
#
# 2. **Rate of Pipe B**:
#    Pipe B can fill the tank in 4 hours. Therefore, its rate is:
#    \[
#    \text{Rate of Pipe B} = \frac{1 \text{ tank}}{4 \text{ hours}} = \frac{1}{4} \text{ tanks per hour}
#    \]
#
# 3. **Rate of Pipe C**:
#    Pipe C can drain the tank in 8 hours. Therefore, its rate (as a negative value since it drains) is:
#    \[
#    \text{Rate of Pipe C} = -\frac{1 \text{ tank}}{8 \text{ hours}} = -\frac{1}{8} \text{ tanks per hour}
#    \]
#
# Now, we can find the combined rate when all three pipes are opened together:
# \[
# \text{Combined Rate} = \text{Rate of Pipe A} + \text{Rate of Pipe B} + \text{Rate of Pipe C}
# \]
# Substituting the rates we calculated:
# \[
# \text{Combined Rate} = \frac{1}{6} + \frac{1}{4} - \frac{1}{8}
# \]
#
# To add these fractions, we need a common denominator. The least common multiple of 6, 4, and 8 is 24. We convert each fraction:
#
# - For \(\frac{1}{6}\):
# \[
# \frac{1}{6} = \frac{4}{24}
# \]
#
# - For \(\frac{1}{4}\):
# \[
# \frac{1}{4} = \frac{6}{24}
# \]
#
# - For \(-\frac{1}{8}\):
# \[
# -\frac{1}{8} = -\frac{3}{24}
# \]
#
# Now we can add them together:
# \[
# \text{Combined Rate} = \frac{4}{24} + \frac{6}{24} - \frac{3}{24} = \frac{4 + 6 - 3}{24} = \frac{7}{24} \text{ tanks per hour}
# \]
#
# Next, we need to find out how long it will take to fill one tank at this combined rate. Let \(t\) be the time in hours to fill the tank:
# \[
# \text{Rate} \times \text{Time} = \text{Amount of tank filled}
# \]
# \[
# \frac{7}{24} \times t = 1 \text{ tank}
# \]
# Solving for \(t\):
# \[
# t = \frac{1}{\frac{7}{24}} = \frac{24}{7} \text{ hours}
# \]
#
# Now, we can convert \(\frac{24}{7}\) into a decimal:
# \[
# \frac{24}{7} \approx 3.42857142857
# \]
#
# Rounding to two decimal places:
# \[
# t \approx 3.43 \text{ hours}
# \]
#
# Thus, the time it takes to fill the tank when all three pipes are opened together is:
# \[
# \text{Exact time} = \frac{24}{7} \text{ hours}, \quad \text{Decimal time} \approx 3.43 \text{ hours}
# \]
#
# ### REASONING MODEL: o4-mini (⏱ 3.22s, total tokens 490, reasoning tokens 256)
#
# Let rate be “tanks per hour.”
# Pipe A’s rate = 1/6, B’s = 1/4, C’s = –1/8.
# Together:
#   R = 1/6 + 1/4 – 1/8
#     = 4/24 + 6/24 – 3/24
#     = 7/24  tank/hour.
# Time = 1 ÷ R = 24/7 hours.
#
# Exact: 24/7 hours.
# Decimal: 24/7 ≈ 3.428571… ≈ 3.43 hours.
#
# ==========================================================================================
# TASK: planning_task
# ==========================================================================================
#
# ### FOUNDATIONAL MODEL: gpt-4o-mini (⏱ 3.88s, total tokens 544, reasoning tokens 0)
#
# To schedule the tasks while satisfying all constraints, we can assign the tasks as follows:
#
# **Worker 1:**
# - T3 (4 hrs): 8:00 AM - 12:00 PM
# - T1 (3 hrs): 12:00 PM - 3:00 PM
#
# **Worker 2:**
# - T2 (2 hrs): 8:00 AM - 10:00 AM
# - T4 (1 hr): 10:00 AM - 11:00 AM
#
# ### Explanation of the Schedule:
#
# 1. **Total Time per Worker:**
#    - Worker 1: T3 (4 hrs) + T1 (3 hrs) = 7 hrs (within the 8-hour limit)
#    - Worker 2: T2 (2 hrs) + T4 (1 hr) = 3 hrs (within the 8-hour limit)
#
# 2. **T3 must start before T1 can start:**
#    - T3 is scheduled from 8:00 AM to 12:00 PM, and T1 starts at 12:00 PM. This satisfies the constraint that T3 must start before T1.
#
# 3. **T2 and T4 must be done by the same worker:**
#    - Both T2 and T4 are assigned to Worker 2. T2 is scheduled from 8:00 AM to 10:00 AM, and T4 is scheduled from 10:00 AM to 11:00 AM. This satisfies the requirement that T2 and T4 must be completed by the same worker.
#
# ### Summary of the Schedule:
# - **Worker 1:**
#   - 8:00 AM - 12:00 PM: T3 (4 hrs)
#   - 12:00 PM - 3:00 PM: T1 (3 hrs)
#
# - **Worker 2:**
#   - 8:00 AM - 10:00 AM: T2 (2 hrs)
#   - 10:00 AM - 11:00 AM: T4 (1 hr)
#
# This schedule effectively utilizes the available time while adhering to all specified constraints.
#
# ### REASONING MODEL: o4-mini (⏱ 8.75s, total tokens 1549, reasoning tokens 1088)
#
# Here’s one simple way to assign and slot the four tasks into an 8-hour day for Worker A and Worker B.
#
# 1. Assignment
#    • Worker A: T2 (2 h) and T4 (1 h)
#    • Worker B: T3 (4 h) and T1 (3 h)
#
# 2. Timeline (both start at 8:00)
#    Worker A:
#      8:00–10:00  T2 (2 h)
#     10:00–11:00  T4 (1 h)
#     11:00–16:00  idle
#    Worker B:
#      8:00–12:00  T3 (4 h)
#     12:00–15:00  T1 (3 h)
#     15:00–16:00  idle
#
# 3. Check of constraints
#  • Total time per worker ≤ 8 h:
#      – Worker A: 2 h + 1 h = 3 h
#      – Worker B: 4 h + 3 h = 7 h
#  • “T3 must start before T1 can start”:
#      – T3 starts at 8:00; T1 starts at 12:00 ⇒ 8:00 < 12:00.
#  • “T2 and T4 must be done by the same worker”:
#      – Both are on Worker A’s schedule.
#
# Thus every constraint is respected.

# %%
#Plotting the latency for all 6 permutations

import matplotlib.pyplot as plt
import numpy as np

tasks = list(prompts.keys())
foundational_times = [next(r["elapsed_sec"] for r in results if r["task"] == t and r["type"] == "foundational") for t in tasks]
reasoning_times    = [next(r["elapsed_sec"] for r in results if r["task"] == t and r["type"] == "reasoning") for t in tasks]

x = np.arange(len(tasks))
width = 0.35

fig, ax = plt.subplots(figsize=(8, 5))
ax.bar(x - width/2, foundational_times, width, label=f"Foundational ({FOUNDATIONAL_MODEL})")
ax.bar(x + width/2, reasoning_times, width, label=f"Reasoning ({REASONING_MODEL})")
ax.set_ylabel("Latency (seconds)")
ax.set_title("Latency: Foundational vs. Reasoning Model")
ax.set_xticks(x)
ax.set_xticklabels(tasks, rotation=15)
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Q1: Test the impact of reasoning_effort on the math problem

math_prompt = prompts["math_problem"]

efforts = ["low", "medium", "high"]
tuning_results = []

for effort in efforts:
    print(f"Running reasoning model with reasoning_effort={effort}...")

    result = call_reasoning(
        math_prompt,
        reasoning_effort=effort,
        max_completion_tokens=2000
    )

    answer = result["answer"]

    # Simple automatic grader
    correct = (
        "24/7" in answer.replace(" ", "")
        and "3.43" in answer
    )

    result["reasoning_effort"] = effort
    result["correct"] = correct

    tuning_results.append(result)

tuning_df = pd.DataFrame(tuning_results)

tuning_df[
    [
        "reasoning_effort",
        "elapsed_sec",
        "prompt_tokens",
        "completion_tokens",
        "reasoning_tokens",
        "total_tokens",
        "correct"
    ]
]
# Out:
# Running reasoning model with reasoning_effort=low...
# Running reasoning model with reasoning_effort=medium...
# Running reasoning model with reasoning_effort=high...
#   reasoning_effort  elapsed_sec  prompt_tokens  completion_tokens  \
# 0              low         2.06             83                308
# 1           medium         3.17             83                534
# 2             high         3.37             83                659
#
#    reasoning_tokens  total_tokens  correct
# 0               128           391     True
# 1               384           617     True
# 2               512           742     True

# %%
# Q1: Summary

for _, row in tuning_df.iterrows():
    print(
        f"{row['reasoning_effort'].upper()}: "
        f"Latency={row['elapsed_sec']}s, "
        f"Reasoning Tokens={row['reasoning_tokens']}, "
        f"Total Tokens={row['total_tokens']}, "
        f"Correct={row['correct']}"
    )
# Out:
# LOW: Latency=2.06s, Reasoning Tokens=128, Total Tokens=391, Correct=True
# MEDIUM: Latency=3.17s, Reasoning Tokens=384, Total Tokens=617, Correct=True
# HIGH: Latency=3.37s, Reasoning Tokens=512, Total Tokens=742, Correct=True
